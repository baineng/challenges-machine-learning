# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
# %matplotlib inline

# %% [markdown]
# # Challenge: Simple Linear Regression (One Feature)

# %% [markdown]
# _The main goal of this notebook is to predict house prices based on one feature of the dataset, The dataset is downloaded from a course of coursera (Machine Learning from the University of Washington). It's some house sales in King County of the United States. ._
#
# ### Objective
# - Write a function to compute the Simple Linear Regression weights using the closed form solution
# - Write a function to make predictions of the output given the input feature
# - Turn the regression around to predict the input/feature given the output
# - Compare two different models for predicting house prices

# %% [markdown]
# ## Load and Exploring Data

# %%
def load_dataset(filepath):
    dtype = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int}
    return pd.read_csv(filepath, compression='zip', dtype=dtype)

df = load_dataset('./data/kc_house_data.csv.zip')
train_df = load_dataset('./data/kc_house_train_data.csv.zip')
test_df = load_dataset('./data/kc_house_test_data.csv.zip')

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#          waterfront          view     condition         grade    sqft_above  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       0.007542      0.234303      3.409430      7.656873   1788.390691
# ...

# %% [markdown]
# ## Task1: to compute the Simple Linear Regression weights using the closed form solution

# %%
def simple_linear_regression(input_feature, output):
    # compute the sum of input_feature and output
    input_sum = input_feature.sum()
    output_sum = output.sum()
    
    # compute the product of the output and the input_feature and its sum
    
    # compute the squared value of the input_feature and its sum
    
    # use the formula for the slope
    
    # use the formula for the intercept
    
    return (intercept, slope)

# %% [markdown]
# let's test it with known input and output

# %%
test_feature = np.asarray(range(5))
test_output = np.asarray(1 + 1*test_feature)
(test_intercept, test_slope) =  simple_linear_regression(test_feature, test_output)
print("Intercept: {}".format(test_intercept))
print("Slope: {}".format(test_slope))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-28453619561d> in <module>()
#       1 test_feature = np.asarray(range(5))
#       2 test_output = np.asarray(1 + 1*test_feature)
# ----> 3 (test_intercept, test_slope) =  simple_linear_regression(test_feature, test_output)
#       4 print("Intercept: {}".format(test_intercept))
#       5 print("Slope: {}".format(test_slope))
#
# <ipython-input-22-53e67c4afc06> in simple_linear_regression(input_feature, output)
#      10     # use the formula for the intercept
#      11
# ---> 12     return (intercept, slope)
#
# NameError: name 'intercept' is not defined
